# %%
pip install plotly==4.14.3
# Out:
# ...
#      |████████████████████████████████| 13.2MB 290kB/s
# ...
#   Found existing installation: plotly 4.4.1
#     Uninstalling plotly-4.4.1:
#       Successfully uninstalled plotly-4.4.1
# ...

# %%
import plotly.graph_objects as go
import pandas as pd

df = pd.read_csv('https://raw.githubusercontent.com/plotly/datasets/master/finance-charts-apple.csv')

fig = go.Figure(go.Scatter(
    x = df['Date'],
    y = df['mavg']
))

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig.update_layout()

# %% [markdown]
# # pass

# %%
# !git clone https://github.com/PacificG/Data-Explorer-Pro-Max.git
# Out:
# Cloning into 'Data-Explorer-Pro-Max'...
# remote: Enumerating objects: 40, done.
# remote: Counting objects: 100% (40/40), done.
# remote: Compressing objects: 100% (35/35), done.
# remote: Total 40 (delta 8), reused 12 (delta 1), pack-reused 0
# Unpacking objects: 100% (40/40), done.

# %%
cd Data-Explorer-Pro-Max/
# Out:
# /content/DEM_SRTM/Data-Explorer-Pro-Max

# %%
pip install streamlit
# Out:
# ...
#      |████████████████████████████████| 8.2MB 6.7MB/s
# ...
#      |████████████████████████████████| 4.6MB 43.4MB/s
# ...
#      |████████████████████████████████| 163kB 49.8MB/s
# ...
#      |████████████████████████████████| 81kB 9.9MB/s
# ...
#      |████████████████████████████████| 112kB 63.3MB/s
# ...
#      |████████████████████████████████| 122kB 57.6MB/s
# ...
#      |████████████████████████████████| 71kB 10.1MB/s
# ...
#   Created wheel for blinker: filename=blinker-1.4-cp37-none-any.whl size=13448 sha256=450ff45c342125957dcebec2f1d2a0f67d131cf8616cf8d505b016130c767b2f
#   Stored in directory: /root/.cache/pip/wheels/92/a0/00/8690a57883956a301d91cf4ec999cc0b258b01e3f548f86e89
# Successfully built blinker
# ERROR: google-colab 1.0.0 has requirement ipykernel~=4.10, but you'll have ipykernel 5.5.3 which is incompatible.
# ...
#   Found existing installation: ipykernel 4.10.1
#     Uninstalling ipykernel-4.10.1:
#       Successfully uninstalled ipykernel-4.10.1
# ...

# %%
cd /content/drive/MyDrive/
# Out:
# /content/drive/MyDrive

# %%
# !wget https://bin.equinox.io/c/4VmDzA7iaHb/ngrok-stable-linux-amd64.zip
# Out:
# --2021-04-12 07:00:44--  https://bin.equinox.io/c/4VmDzA7iaHb/ngrok-stable-linux-amd64.zip
# Resolving bin.equinox.io (bin.equinox.io)... 34.194.108.77, 54.164.22.162, 3.226.107.193, ...
# Connecting to bin.equinox.io (bin.equinox.io)|34.194.108.77|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 14746350 (14M) [application/octet-stream]
# Saving to: ‘ngrok-stable-linux-amd64.zip’
#
# ngrok-stable-linux- 100%[===================>]  14.06M  17.4MB/s    in 0.8s
#
# 2021-04-12 07:00:45 (17.4 MB/s) - ‘ngrok-stable-linux-amd64.zip’ saved [14746350/14746350]

# %%
# !unzip ngrok-stable-linux-amd64.zip
# Out:
# Archive:  ngrok-stable-linux-amd64.zip
#   inflating: ngrok

# %%
get_ipython().system_raw('./ngrok http 8501 &')

# %%
# !curl -s http://localhost:4040/api/tunnels | python3 -c \
    'import sys, json; print("Execute the next cell and the go to the following URL: " +json.load(sys.stdin)["tunnels"][0]["public_url"])'
# Out:
# Execute the next cell and the go to the following URL: https://bf1a89d8b701.ngrok.io

# %%
# !streamlit run /content/DEM_SRTM/Data-Explorer-Pro-Max/explore.py

# %%
# !wget https://swat.tamu.edu/docs/swat/india-dataset/2012/DEM_SRTM.7z
# Out:
# --2021-04-12 06:26:13--  https://swat.tamu.edu/docs/swat/india-dataset/2012/DEM_SRTM.7z
# Resolving swat.tamu.edu (swat.tamu.edu)... 128.194.16.50
# Connecting to swat.tamu.edu (swat.tamu.edu)|128.194.16.50|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 943925487 (900M) [application/x-zip-compressed]
# Saving to: ‘DEM_SRTM.7z’
#
# DEM_SRTM.7z         100%[===================>] 900.20M  80.4MB/s    in 12s
#
# 2021-04-12 06:26:24 (77.2 MB/s) - ‘DEM_SRTM.7z’ saved [943925487/943925487]

# %%
# !sudo apt install p7zip
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# p7zip is already the newest version (16.02+dfsg-6).
# p7zip set to manually installed.
# 0 upgraded, 0 newly installed, 0 to remove and 31 not upgraded.

# %%
!7z x DEM_SRTM.7z
# Out:
# 7-Zip [64] 16.02 : Copyright (c) 1999-2016 Igor Pavlov : 2016-05-21
# p7zip Version 16.02 (locale=en_US.UTF-8,Utf16=on,HugeFiles=on,64 bits,2 CPUs Intel(R) Xeon(R) CPU @ 2.00GHz (50653),ASM,AES-NI)
#
# Scanning the drive for archives:
# 1 file, 943925487 bytes (901 MiB)
#
# Extracting archive: DEM_SRTM.7z
# --
# Path = DEM_SRTM.7z
# Type = 7z
# Physical Size = 943925487
# Headers Size = 932
# Method = LZMA:24
# Solid = +
# Blocks = 1
#
# Everything is Ok
#
# Folders: 1
# Files: 45
# Size:       1033763787
# Compressed: 943925487

# %%
cd DEM_SRTM/
# Out:
# /content/DEM_SRTM

# %%
!7z e *zip
# Out:
# 7-Zip [64] 16.02 : Copyright (c) 1999-2016 Igor Pavlov : 2016-05-21
# p7zip Version 16.02 (locale=en_US.UTF-8,Utf16=on,HugeFiles=on,64 bits,2 CPUs Intel(R) Xeon(R) CPU @ 2.00GHz (50653),ASM,AES-NI)
#
# Scanning the drive for archives:
# 1 file, 33484519 bytes (32 MiB)
#
# Extracting archive: srtm_49_07.zip
# --
# Path = srtm_49_07.zip
# Type = zip
# Physical Size = 33484519
#
#
# No files to process
# Everything is Ok
#
# Files: 0
# Size:       0
# Compressed: 33484519

# %% [markdown]
# # ok

# %%
path = "/content/drive/MyDrive/workspace/BDAProject"

# %%
cd $path
# Out:
# /content/drive/MyDrive/workspace/BDAProject

# %%
# %%capture
pip install -r requirements.txt

# %%
import importlib
import train2, model
import pandas as pd
import numpy as np

# %%
importlib.reload(model)
importlib.reload(train2)
# Out:
# <module 'train2' from '/content/drive/My Drive/workspace/BDAProject/train2.py'>

# %%
cat train.py

# %%
# model.save_model(m1, path)

# %%
# train.put_api_key('b0dc4cf9f6365bb21ad1bfdf2846fcde')

# %%
df = pd.read_csv('df.csv')

# %%
df.tail()
# Out:
#                          ds          y
# 107251  2021-03-27 19:00:00  27.764906
# 107252  2021-03-27 20:00:00  27.115021
# 107253  2021-03-27 21:00:00  26.600369
# 107254  2021-03-27 22:00:00  26.160551
# 107255  2021-03-27 23:00:00  25.729177

# %%
train2.train_online(path, 'b0dc4cf9f6365bb21ad1bfdf2846fcde')
# Out:
# INFO:numexpr.utils:NumExpr defaulting to 2 threads.
# /content/drive/My Drive/workspace/BDAProject/train2.py:49: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                      ds       yhat  yactual
# 0   2021-03-28 00:00:00  25.136871    20.00
# 1   2021-03-28 01:00:00  24.722365    21.16
# 2   2021-03-28 02:00:00  24.475863    23.00
# 3   2021-03-28 03:00:00  24.566381    24.00
# 4   2021-03-28 04:00:00  25.125486    27.10
# ..                  ...        ...      ...
# 407 2021-04-13 23:00:00  26.704980    23.00
# 408 2021-04-14 00:00:00  26.247959    22.00
# 409 2021-04-14 01:00:00  25.825606    22.58
# 410 2021-04-14 02:00:00  25.571272    23.79
# 411 2021-04-14 03:00:00  25.654027    25.58
#
# [412 rows x 3 columns]
# ...

# %%
history.openweathermap.org/data/2.5/aggregated/year?q={},{country code}&appid={'b0dc4cf9f6365bb21ad1bfdf2846fcde'}
# Out:
# bombay.csv
# bengaluru.csv
# hyderabad.csv
# delhi.csv
# nagpur.csv
# kanpur.csv
# jaipur.csv
# pune.csv

# %% [markdown]
# # ---

# %%
import pandas as pd
crops = pd.read_csv('apy.csv')
crops[['District_Name', 'Crop']].value_counts().index
# Out:
# MultiIndex([(   'AURANGABAD',              'Maize'),
#             (      'BIJAPUR',              'Maize'),
#             ('KARBI ANGLONG',               'Rice'),
#             (        'SARAN',              'Maize'),
#             (   'JALPAIGURI',               'Rice'),
#             (       'MYSORE',               'Ragi'),
#             (     'VAISHALI',              'Maize'),
#             (      'BHOJPUR',              'Maize'),
#             (    'MADHEPURA',              'Maize'),
#             (      'DARRANG',               'Rice'),
#             ...
#             (       'GUNTUR',       'other fibres'),
#             (    'GURDASPUR',              'Bajra'),
#             (         'MAHE',       'Dry chillies'),
#             (      'SIRMAUR',             'Ginger'),
#             (    'GURDASPUR',  'Moong(Green Gram)'),
#             (    'GURDASPUR',               'Moth'),
#             (    'GURDASPUR', 'Other  Rabi pulses'),
# ...

# %%
pd.DataFrame()

# %%
crops[crops['Crop'] == 'Groundnut'][crops['State_Name'] == 'Karnataka']['District_Name'].value_counts()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
# UTTAR KANNAD       37
# TUMKUR             36
# BELGAUM            36
# BIDAR              36
# SHIMOGA            36
# BELLARY            36
# GULBARGA           36
# CHIKMAGALUR        35
# DHARWAD            35
# BIJAPUR            35
# CHITRADURGA        35
# HASSAN             35
# RAICHUR            35
# DAVANGERE          34
# MYSORE             34
# KOLAR              33
# GADAG              33
# BANGALORE RURAL    33
# HAVERI             33
# BAGALKOT           33
# KOPPAL             33
# MANDYA             32
# BENGALURU URBAN    32
# CHAMARAJANAGAR     31
# KODAGU             19
# UDUPI              18
# CHIKBALLAPUR       16
# RAMANAGARA         16
# YADGIR             11
# DAKSHIN KANNAD      1
# Name: District_Name, dtype: int64

# %%
crops.shape
# Out:
# (246091, 7)

# %%
crops.groupby(['State_Name', 'Crop_Year']).mean()
# Out:
#                                                Area    Production
# State_Name                  Crop_Year
# Andaman and Nicobar Islands 2000        2119.904762  4.240996e+06
#                             2001        2572.687500  5.607419e+06
#                             2002        2380.600000  4.967744e+06
#                             2003        2357.863158  5.015603e+06
#                             2004        2384.672105  4.588763e+06
# ...                                             ...           ...
# West Bengal                 2010       14407.310139  7.631204e+04
#                             2011       15924.763860  7.551904e+04
#                             2012       16022.320408  7.958747e+04
#                             2013       16562.763975  7.847056e+04
#                             2014       16020.656064  8.664891e+04
#
# [519 rows x 2 columns]

# %%
crops.head()
# Out:
#                     State_Name District_Name  ...    Area Production
# 0  Andaman and Nicobar Islands      NICOBARS  ...  1254.0     2000.0
# 1  Andaman and Nicobar Islands      NICOBARS  ...     2.0        1.0
# 2  Andaman and Nicobar Islands      NICOBARS  ...   102.0      321.0
# 3  Andaman and Nicobar Islands      NICOBARS  ...   176.0      641.0
# 4  Andaman and Nicobar Islands      NICOBARS  ...   720.0      165.0
#
# [5 rows x 7 columns]

# %%
train.train_online(path, m1)
# Out:
#                     ds       yhat  yactual
# 0  2021-03-28 00:00:00  25.136871    20.00
# 1  2021-03-28 01:00:00  24.722365    21.16
# 2  2021-03-28 02:00:00  24.475863    23.00
# 3  2021-03-28 03:00:00  24.566381    24.00
# 4  2021-03-28 04:00:00  25.125486    27.10
# ..                 ...        ...      ...
# 94 2021-03-31 22:00:00  26.459868    24.00
# 95 2021-03-31 23:00:00  26.028132    23.00
# 96 2021-04-01 00:00:00  25.578855    23.00
# 97 2021-04-01 01:00:00  25.164569    22.57
# 98 2021-04-01 02:00:00  24.918588    24.00
#
# [99 rows x 3 columns]

# %%
m1.predict(future)

# %% [markdown]
# # junk

# %%
# !gdown https://drive.google.com/uc?id=1XrHVCImP4d1m9ZF2tuZ61wN_1DskpTo9
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1XrHVCImP4d1m9ZF2tuZ61wN_1DskpTo9
# To: /content/archive.zip
# 12.4MB [00:00, 58.0MB/s]

# %%
# !unzip archive.zip
# Out:
# Archive:  archive.zip
# replace bengaluru.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: N

# %%
import pandas as pd

# %%
# %%capture
# !pip install pystan
# !pip install fbprophet
import pandas as pd
from fbprophet import Prophet

# %%
cd /content/drive/MyDrive/workspace/BDAProject/
# Out:
# /content/drive/MyDrive/workspace/BDAProject

# %%
import pandas as pd
b = pd.read_csv('data/bengaluru.csv', index_col=None)

# %%
b.head()
# Out:
#              date_time  maxtempC  ...  winddirDegree  windspeedKmph
# 0  2009-01-01 00:00:00        27  ...            109              8
# 1  2009-01-01 01:00:00        27  ...             85              6
# 2  2009-01-01 02:00:00        27  ...             61              4
# 3  2009-01-01 03:00:00        27  ...             37              3
# 4  2009-01-01 04:00:00        27  ...             45              3
#
# [5 rows x 25 columns]

# %%
def year(st):
  return st[:4]

def season(st):
  mn = int(st[5:7])
  if mn in range(7,11):
    return 'Kharif'
  else:
    return 'Rabi'

# %%
month('2009-01')
# Out:
# 1

# %%
b['year'] = b['date_time'].apply(year)
b['month'] = b['date_time'].apply(month)

# %%
b.head()
# Out:
#              date_time  maxtempC  mintempC  ...  windspeedKmph  year  month
# 0  2009-01-01 00:00:00        27        12  ...              8  2009     01
# 1  2009-01-01 01:00:00        27        12  ...              6  2009     01
# 2  2009-01-01 02:00:00        27        12  ...              4  2009     01
# 3  2009-01-01 03:00:00        27        12  ...              3  2009     01
# 4  2009-01-01 04:00:00        27        12  ...              3  2009     01
#
# [5 rows x 27 columns]

# %%
b = b[['year','month', 'tempC', 'humidity', 'precipMM']]

# %%
dfnew = b[['date_time', 'humidity', 'tempC']].groupby(['date_time']).mean()

# %%
dfnew['precipMM'] = b[['date_time', 'precipMM']].groupby(['date_time']).sum()['precipMM']

# %%
dfnew
# Out:
#             humidity      tempC  precipMM
# date_time
# 2009       69.605479  23.406735     707.0
# 2010       71.526370  23.627511     799.9
# 2011       66.415183  23.389612     496.6
# 2012       62.953324  23.898224     366.7
# 2013       64.752055  23.810046     389.7
# 2014       63.027283  24.060046     395.1
# 2015       65.878425  23.849087     539.5
# 2016       63.342668  23.949226     447.8
# 2017       63.423059  24.145434     711.6
# 2018       60.087557  24.631050     649.8
# 2019       62.811986  25.017466    1988.0
# 2020       78.125000  21.708333       2.9

# %%
dfnew.iloc[[0,1,2,3,4, 5]]
# Out:
#             humidity      tempC  precipMM
# date_time
# 2009       69.605479  23.406735     707.0
# 2010       71.526370  23.627511     799.9
# 2011       66.415183  23.389612     496.6
# 2012       62.953324  23.898224     366.7
# 2013       64.752055  23.810046     389.7
# 2014       63.027283  24.060046     395.1

# %%
dfnew.loc[['2009', '2010', '2011', '2012', '2013', '2014']]
# Out:
#             humidity      tempC  precipMM
# date_time
# 2009       69.605479  23.406735     707.0
# 2010       71.526370  23.627511     799.9
# 2011       66.415183  23.389612     496.6
# 2012       62.953324  23.898224     366.7
# 2013       64.752055  23.810046     389.7
# 2014       63.027283  24.060046     395.1

# %%
year = '2009'
dfnew.loc[[year]]['tempC'][0]
# Out:
# 23.40673515981735

# %%
year = '2009'
print(year)
# Out:
# 2009

# %%
def addTemp(year):
    if year in ['2009', '2010', '2011', '2012', '2013', '2014']:
        print(year)
        return dfnew.loc[[year]]['tempC'][0]
    else:
        return np.nan

addTemp('2010')
# Out:
# 2010
# 23.627511415525113

# %%
ben = pd.read_csv('data/bnew.csv', index_col='date_time')

# %%
ben.loc[[2009]]['tempC']
# Out:
# date_time
# 2009    23.406735
# Name: tempC, dtype: float64

# %%
b.columns
# Out:
# Index(['date_time', 'maxtempC', 'mintempC', 'totalSnow_cm', 'sunHour',
#        'uvIndex', 'uvIndex.1', 'moon_illumination', 'moonrise', 'moonset',
#        'sunrise', 'sunset', 'DewPointC', 'FeelsLikeC', 'HeatIndexC',
#        'WindChillC', 'WindGustKmph', 'cloudcover', 'humidity', 'precipMM',
#        'pressure', 'tempC', 'visibility', 'winddirDegree', 'windspeedKmph'],
#       dtype='object')

# %%
m = Prophet()

# %%
df = b.rename(columns={'date_time':'ds', 'tempC':'y'})

# %%
df = df[['ds', 'y']]

# %%
import datetime

# %%
int(datetime.datetime.timestamp(pd.Timestamp('2020-01-01 23:00:00')))
# Out:
# 1577919600

# %% [markdown]
# 1577916000

# %%
1577919600 - 1577916000
# Out:
# 3600

# %%
list(df['ds'])[-1]
# Out:
# '2020-01-01 23:00:00'

# %%
df.to_csv("/content/drive/MyDrive/workspace/BDAProject/df.csv")

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96432 entries, 0 to 96431
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ds      96432 non-null  object
#  1   y       96432 non-null  int64
# dtypes: int64(1), object(1)
# memory usage: 1.5+ MB

# %%
m.fit(df)
# Out:
# INFO:numexpr.utils:NumExpr defaulting to 2 threads.

# %%
future = m.make_future_dataframe(451*24,freq="Y")

# %%
future.head()
# Out:
#                    ds
# 0 2009-01-01 00:00:00
# 1 2009-01-01 01:00:00
# 2 2009-01-01 02:00:00
# 3 2009-01-01 03:00:00
# 4 2009-01-01 04:00:00

# %%
future.tail()
# Out:
#                         ds
# 107251 2021-03-27 19:00:00
# 107252 2021-03-27 20:00:00
# 107253 2021-03-27 21:00:00
# 107254 2021-03-27 22:00:00
# 107255 2021-03-27 23:00:00

# %%
forecast = m.predict(future)

# %%
dfnew = forecast[['ds', 'yhat']].rename(columns={'yhat':'y'})

# %%
dfnew = dfnew.iloc[dfnew.shape[0] - 451*24:, :]

# %%
df.tail()
# Out:
#                         ds   y
# 96427  2020-01-01 19:00:00  23
# 96428  2020-01-01 20:00:00  22
# 96429  2020-01-01 21:00:00  21
# 96430  2020-01-01 22:00:00  20
# 96431  2020-01-01 23:00:00  20

# %%
dfnew.head()
# Out:
#                        ds          y
# 96432 2020-01-02 00:00:00  18.026288
# 96433 2020-01-02 01:00:00  17.609477
# 96434 2020-01-02 02:00:00  17.360979
# 96435 2020-01-02 03:00:00  17.449819
# 96436 2020-01-02 04:00:00  18.007573

# %%
dfsave = df.append(dfnew)
dfsave.tail()
# Out:
#                          ds          y
# 107251  2021-03-27 19:00:00  27.764906
# 107252  2021-03-27 20:00:00  27.115021
# 107253  2021-03-27 21:00:00  26.600369
# 107254  2021-03-27 22:00:00  26.160551
# 107255  2021-03-27 23:00:00  25.729177

# %%
dfsave.head()
# Out:
#                     ds     y
# 0  2009-01-01 00:00:00  14.0
# 1  2009-01-01 01:00:00  14.0
# 2  2009-01-01 02:00:00  13.0
# 3  2009-01-01 03:00:00  12.0
# 4  2009-01-01 04:00:00  14.0

# %%
dfsave.tail()
# Out:
#                          ds          y
# 107251  2021-03-27 19:00:00  27.764906
# 107252  2021-03-27 20:00:00  27.115021
# 107253  2021-03-27 21:00:00  26.600369
# 107254  2021-03-27 22:00:00  26.160551
# 107255  2021-03-27 23:00:00  25.729177

# %%
m = Prophet()
m.fit(dfsave)

# %%
dfsave.to_csv('/content/drive/MyDrive/workspace/BDAProject/df.csv', index=False)

# %%
dfnew = pd.read_csv('/content/drive/MyDrive/workspace/BDAProject/df.csv')
dfnew.head()
# Out:
#                     ds     y
# 0  2009-01-01 00:00:00  14.0
# 1  2009-01-01 01:00:00  14.0
# 2  2009-01-01 02:00:00  13.0
# 3  2009-01-01 03:00:00  12.0
# 4  2009-01-01 04:00:00  14.0

# %%
dfnew.tail()
# Out:
#         Unnamed: 0                   ds          y
# 107251      107251  2021-03-27 19:00:00  27.764906
# 107252      107252  2021-03-27 20:00:00  27.115021
# 107253      107253  2021-03-27 21:00:00  26.600369
# 107254      107254  2021-03-27 22:00:00  26.160551
# 107255      107255  2021-03-27 23:00:00  25.729177

# %%
lasttime = list(dfsave.iloc[dfsave.shape[0]-1:, 0])[0]
tp = int(datetime.datetime.timestamp(lasttime))

# %%
now = datetime.datetime.now()
e = datetime.datetime.timestamp(now)
e = int(e - (e%3600)) + 3600

# %%
e
# Out:
# 1617238800

# %%
API = 'b0dc4cf9f6365bb21ad1bfdf2846fcde'

# %%
import requests
data = requests.get(f'http://history.openweathermap.org/data/2.5/history/city?id={1277333}&type=hour&start={tp}&end={e}&appid={API}')

# %%
import requests
data = requests.get(f'http://history.openweathermap.org/data/2.5/aggregated/year?id={1277333}&appid={API}')

# %%
import json
dic = data.json()

# %%
for r in dic['result']:
  print(r['day'], r['month'], r['humidity'])
# Out:
# 1 1 {'min': 15, 'max': 100, 'median': 87.5, 'mean': 78.51, 'p25': 59.5, 'p75': 99, 'st_dev': 23.7, 'num': 216}
# 2 1 {'min': 23, 'max': 100, 'median': 86.5, 'mean': 76.17, 'p25': 59, 'p75': 99, 'st_dev': 24.95, 'num': 216}
# 3 1 {'min': 19, 'max': 100, 'median': 86, 'mean': 74.26, 'p25': 52.5, 'p75': 99, 'st_dev': 26.36, 'num': 216}
# 4 1 {'min': 21, 'max': 100, 'median': 81, 'mean': 73.01, 'p25': 48, 'p75': 99, 'st_dev': 26.38, 'num': 215}
# 5 1 {'min': 22, 'max': 100, 'median': 78, 'mean': 74.19, 'p25': 52, 'p75': 99, 'st_dev': 25.23, 'num': 216}
# 6 1 {'min': 24, 'max': 100, 'median': 87, 'mean': 75.5, 'p25': 49, 'p75': 100, 'st_dev': 25.71, 'num': 216}
# 7 1 {'min': 24, 'max': 100, 'median': 82.5, 'mean': 75.42, 'p25': 52, 'p75': 99, 'st_dev': 24.43, 'num': 216}
# 8 1 {'min': 20, 'max': 100, 'median': 77, 'mean': 71.97, 'p25': 45.5, 'p75': 99, 'st_dev': 25.66, 'num': 216}
# ...

# %%
len(dic['list'])
# Out:
# 99

# %%
temp = {}
for da in dic['list']:
  temp[datetime.datetime.fromtimestamp(da['dt']).__str__()] = da['main']['temp'] - 273.15

# %%
df = pd.DataFrame(list(temp.items()),columns = ['ds','y'])
df
# Out:
#                      ds      y
# 0   2021-03-27 23:00:00  20.00
# 1   2021-03-28 00:00:00  20.00
# 2   2021-03-28 01:00:00  21.16
# 3   2021-03-28 02:00:00  23.00
# 4   2021-03-28 03:00:00  24.00
# ..                  ...    ...
# 94  2021-03-31 21:00:00  24.00
# 95  2021-03-31 22:00:00  24.00
# 96  2021-03-31 23:00:00  23.00
# 97  2021-04-01 00:00:00  23.00
# 98  2021-04-01 01:00:00  22.57
#
# [99 rows x 2 columns]

# %%
def stan_init(m):
    """Retrieve parameters from a trained model.
    
    Retrieve parameters from a trained model in the format
    used to initialize a new Stan model.
    
    Parameters
    ----------
    m: A trained model of the Prophet class.
    
    Returns
    -------
    A Dictionary containing retrieved parameters of m.
    
    """
    res = {}
    for pname in ['k', 'm', 'sigma_obs']:
        res[pname] = m.params[pname][0][0]
    for pname in ['delta', 'beta']:
        res[pname] = m.params[pname][0]
    return res

# %%
stan_init(m1)
# Out:
# {'beta': array([ 6.10535197e-02, -5.00628441e-02, -1.32053433e-02, -4.28012009e-02,
#         -5.63586241e-03,  6.35882417e-03,  4.25615888e-03, -2.81157438e-04,
#         -4.14933526e-03,  1.58308243e-03,  7.17099681e-04, -1.18607626e-03,
#         -1.07565076e-03, -7.98450527e-05,  3.22381359e-03,  4.16902339e-03,
#          1.64578017e-03, -2.38068272e-03,  9.12567315e-04,  1.19047277e-03,
#          6.81974131e-04,  3.22626915e-04,  4.90423437e-04,  9.68477176e-05,
#          1.36880963e-04, -5.46331045e-04, -1.06564908e-02, -1.11503947e-01,
#         -1.67916510e-02,  1.81383616e-02,  2.13458871e-04,  2.61426999e-03,
#          2.96574381e-05,  3.38072669e-04]),
#  'delta': array([ 0.89627731,  0.0862393 , -0.91249226,  0.50652304, -0.20363349,
#          0.69978754, -0.5224804 ,  0.20030679, -0.13272106, -0.00793577,
#         -0.35810488,  0.03512853,  1.4481957 , -1.88352798,  0.10286514,
#          1.7659221 , -1.25193989, -0.27814138,  0.14947002, -0.04865865,
# ...

# %%
m1 = Prophet(yearly_seasonality=True).fit(dfsave)

# %%
m2 = Prophet(yearly_seasonality=True, weekly_seasonality=True).fit(df.iloc[1:,:], init=stan_init(m1))

# %%
temp
# Out:
# {'2021-03-27 23:00:00': 20.0,
#  '2021-03-28 00:00:00': 20.0,
#  '2021-03-28 01:00:00': 21.160000000000025,
#  '2021-03-28 02:00:00': 23.0,
#  '2021-03-28 03:00:00': 24.0,
#  '2021-03-28 04:00:00': 27.100000000000023,
#  '2021-03-28 05:00:00': 29.879999999999995,
#  '2021-03-28 06:00:00': 30.700000000000045,
#  '2021-03-28 07:00:00': 31.230000000000018,
#  '2021-03-28 08:00:00': 31.920000000000016,
#  '2021-03-28 09:00:00': 31.74000000000001,
#  '2021-03-28 10:00:00': 32.400000000000034,
#  '2021-03-28 11:00:00': 32.48000000000002,
#  '2021-03-28 12:00:00': 31.99000000000001,
#  '2021-03-28 13:00:00': 31.79000000000002,
#  '2021-03-28 14:00:00': 30.58000000000004,
#  '2021-03-28 15:00:00': 29.04000000000002,
#  '2021-03-28 16:00:00': 26.58000000000004,
#  '2021-03-28 17:00:00': 25.58000000000004,
#  '2021-03-28 18:00:00': 25.57000000000005,
#  '2021-03-28 19:00:00': 25.170000000000016,
#  '2021-03-28 20:00:00': 23.0,
#  '2021-03-28 21:00:00': 22.0,
#  '2021-03-28 22:00:00': 22.0,
# ...

# %%
24*7
# Out:
# 168

# %%
dt = datetime.datetime.fromtimestamp(1500000000)
print(dt)
# Out:
# 2017-07-14 02:40:00

# %%
def timeSeries(df, datecol, pred):
  b = df.rename(columns={datecol:'ds', pred:'y'})[['ds', 'y']]
  print('dataframe \n', b.head())
  btest = b.tail(365*24)[['ds','y']]
  btest['ds'] = pd.to_datetime(btest['ds'])
  btrain = b.iloc[:b.shape[0] - 365*24, :][['ds', 'y']]
  m = Prophet()
  m.fit(btrain)
  future = m.make_future_dataframe(periods=365*24, freq='H')
  forecast = m.predict(future)
  dftest = pd.merge(forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']], btest, on='ds')
  print(dftest.tail(24))
  print('-'*100)
  m.plot(forecast)
  m.plot_components(forecast)

# %%
timeSeries(b, 'date_time', 'tempC')
# Out:
# dataframe
#                      ds   y
# 0  2009-01-01 00:00:00  14
# 1  2009-01-01 01:00:00  14
# 2  2009-01-01 02:00:00  13
# 3  2009-01-01 03:00:00  12
# 4  2009-01-01 04:00:00  14
#                       ds       yhat  yhat_lower  yhat_upper   y
# 8736 2020-01-01 00:00:00  18.631445   14.569431   22.129820  19
# 8737 2020-01-01 01:00:00  18.210563   14.373858   21.812454  19
# 8738 2020-01-01 02:00:00  17.966901   14.195136   21.556331  19
# 8739 2020-01-01 03:00:00  18.084505   14.288474   21.727862  19
# 8740 2020-01-01 04:00:00  18.703389   14.735131   22.169967  19
# 8741 2020-01-01 05:00:00  19.850618   16.007660   23.205144  19
# 8742 2020-01-01 06:00:00  21.417985   17.803518   24.826257  19
# 8743 2020-01-01 07:00:00  23.192582   19.335193   26.749693  20
# 8744 2020-01-01 08:00:00  24.918916   20.947012   28.358690  21
# 8745 2020-01-01 09:00:00  26.362029   22.730589   30.078201  22
# 8746 2020-01-01 10:00:00  27.351299   23.667172   31.007959  23
# ...

# %%
timeSeries(pd.read_csv('delhi.csv', index_col=None), 'date_time', 'tempC')
# Out:
# dataframe
#                      ds   y
# 0  2009-01-01 00:00:00  10
# 1  2009-01-01 01:00:00  10
# 2  2009-01-01 02:00:00   9
# 3  2009-01-01 03:00:00   9
# 4  2009-01-01 04:00:00   9
#                       ds       yhat  yhat_lower  yhat_upper   y
# 8736 2020-01-01 00:00:00  12.626452    0.146398   23.197287  11
# 8737 2020-01-01 01:00:00  11.969008   -0.318914   22.214172  11
# 8738 2020-01-01 02:00:00  11.444584   -0.697247   22.395322  11
# 8739 2020-01-01 03:00:00  11.392372   -1.176577   21.774931  11
# 8740 2020-01-01 04:00:00  12.024213   -0.581695   23.393538  11
# 8741 2020-01-01 05:00:00  13.297308    1.304114   23.812639  11
# 8742 2020-01-01 06:00:00  14.968092    2.773989   25.475063  11
# 8743 2020-01-01 07:00:00  16.758467    4.724219   27.736282  12
# 8744 2020-01-01 08:00:00  18.477714    6.255250   29.390120  12
# 8745 2020-01-01 09:00:00  20.009037    8.259116   31.119723  13
# 8746 2020-01-01 10:00:00  21.216495    8.686619   31.182050  14
# ...

# %%
import os

# %%
timeSeries(pd.read_csv('pune.csv', index_col=None), 'date_time', 'tempC')
# Out:
# dataframe
#                      ds   y
# 0  2009-01-01 00:00:00  13
# 1  2009-01-01 01:00:00  14
# 2  2009-01-01 02:00:00  14
# 3  2009-01-01 03:00:00  15
# 4  2009-01-01 04:00:00  16
#                       ds       yhat  yhat_lower  yhat_upper   y
# 8736 2020-01-01 00:00:00  18.986832   14.822402   23.635300  20
# 8737 2020-01-01 01:00:00  18.629797   14.460534   23.326163  19
# 8738 2020-01-01 02:00:00  18.440675   14.240931   22.716345  19
# 8739 2020-01-01 03:00:00  18.577310   14.418696   22.884566  18
# 8740 2020-01-01 04:00:00  19.177080   14.956033   23.552890  18
# 8741 2020-01-01 05:00:00  20.306504   15.854543   24.991807  18
# 8742 2020-01-01 06:00:00  21.910685   17.627981   26.513254  19
# 8743 2020-01-01 07:00:00  23.794325   19.759848   28.507858  20
# 8744 2020-01-01 08:00:00  25.663020   21.486405   30.447406  21
# 8745 2020-01-01 09:00:00  27.217278   22.930891   31.479206  23
# 8746 2020-01-01 10:00:00  28.249906   23.788920   32.608936  24
# ...

# %%
b.rename(columns={'date_time':'ds', 'tempC':'y'}, inplace=True)
b.head()
# Out:
#                     ds  maxtempC  ...  winddirDegree  windspeedKmph
# 0  2009-01-01 00:00:00        27  ...            109              8
# 1  2009-01-01 01:00:00        27  ...             85              6
# 2  2009-01-01 02:00:00        27  ...             61              4
# 3  2009-01-01 03:00:00        27  ...             37              3
# 4  2009-01-01 04:00:00        27  ...             45              3
#
# [5 rows x 25 columns]

# %% [markdown]
# 4 year

# %% [markdown]
# ![WhatsApp Image 2021-03-10 at 8.27.47 AM.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# Month

# %% [markdown]
# ![WhatsApp Image 2021-03-10 at 8.32.25 AM.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# 7 days

# %% [markdown]
# ![WhatsApp Image 2021-03-10 at 8.35.37 AM.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# 9 years

# %% [markdown]
# ![WhatsApp Image 2021-03-10 at 8.44.48 AM.jpeg](data:image/jpeg;base64,...)

# %%
import numpy as np

# %%
btest = b.tail(365*24)[['ds','y', 'mintempC', 'maxtempC']]
btest.head()
btest['ds'] = pd.to_datetime(btest['ds'])
btest.dtypes
# Out:
# ds          datetime64[ns]
# y                    int64
# mintempC             int64
# maxtempC             int64
# dtype: object

# %%
btrain = b.iloc[:96432 - 365*24, :][['ds', 'y']]
btrain.tail()
# Out:
#                         ds   y
# 87667  2019-01-01 19:00:00  22
# 87668  2019-01-01 20:00:00  21
# 87669  2019-01-01 21:00:00  19
# 87670  2019-01-01 22:00:00  19
# 87671  2019-01-01 23:00:00  18

# %% [markdown]
# Using facebook's prophet

# %%
b_pr = btrain[['ds', 'y']]
b_pr.head()
# Out:
#                     ds   y
# 0  2009-01-01 00:00:00  14
# 1  2009-01-01 01:00:00  14
# 2  2009-01-01 02:00:00  13
# 3  2009-01-01 03:00:00  12
# 4  2009-01-01 04:00:00  14

# %%
m = Prophet()
m.fit(b_pr)

# %%
future = m.make_future_dataframe(periods=365*24, freq='H')
future.tail()
# Out:
#                        ds
# 96427 2020-01-01 19:00:00
# 96428 2020-01-01 20:00:00
# 96429 2020-01-01 21:00:00
# 96430 2020-01-01 22:00:00
# 96431 2020-01-01 23:00:00

# %%
forecast = m.predict(future)
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
# Out:
#                        ds       yhat  yhat_lower  yhat_upper
# 96427 2020-01-01 19:00:00  21.100686   17.270093   24.928093
# 96428 2020-01-01 20:00:00  20.459610   16.447550   24.188380
# 96429 2020-01-01 21:00:00  19.964123   15.930918   23.776822
# 96430 2020-01-01 22:00:00  19.544205   15.562843   23.297333
# 96431 2020-01-01 23:00:00  19.124904   15.320618   22.825525

# %%
btest.tail()
# Out:
#                        ds   y  mintempC  maxtempC
# 96427 2020-01-01 19:00:00  23        18        26
# 96428 2020-01-01 20:00:00  22        18        26
# 96429 2020-01-01 21:00:00  21        18        26
# 96430 2020-01-01 22:00:00  20        18        26
# 96431 2020-01-01 23:00:00  20        18        26

# %%
fig1 = m.plot(forecast)

# %%
fig2 = m.plot_components(forecast)

# %%
from fbprophet.plot import plot_plotly, plot_components_plotly

plot_plotly(m, forecast)

# %%
# %%capture
pip install gluonts

# %%
# %%capture
pip install mxnet

# %%
# %matplotlib inline
import mxnet as mx
from mxnet import gluon
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import json

# %%
from gluonts.dataset.repository.datasets import get_dataset, dataset_recipes
from gluonts.dataset.util import to_pandas

# %%
dataset = get_dataset("m4_hourly", regenerate=True)
# Out:
# saving time-series into /root/.mxnet/gluon-ts/datasets/m4_hourly/train/data.json
# saving time-series into /root/.mxnet/gluon-ts/datasets/m4_hourly/test/data.json

# %%
entry = next(iter(dataset.train))
train_series = to_pandas(entry)

# %%
train_series
# Out:
# 1750-01-01 00:00:00    605.0
# 1750-01-01 01:00:00    586.0
# 1750-01-01 02:00:00    586.0
# 1750-01-01 03:00:00    559.0
# 1750-01-01 04:00:00    511.0
#                        ...
# 1750-01-29 23:00:00    790.0
# 1750-01-30 00:00:00    784.0
# 1750-01-30 01:00:00    752.0
# 1750-01-30 02:00:00    739.0
# 1750-01-30 03:00:00    684.0
# Freq: H, Length: 700, dtype: float32

# %%
b.head()
# Out:
#              date_time  maxtempC  ...  winddirDegree  windspeedKmph
# 0  2009-01-01 00:00:00        27  ...            109              8
# 1  2009-01-01 01:00:00        27  ...             85              6
# 2  2009-01-01 02:00:00        27  ...             61              4
# 3  2009-01-01 03:00:00        27  ...             37              3
# 4  2009-01-01 04:00:00        27  ...             45              3
#
# [5 rows x 25 columns]

# %%
from gluonts.model.simple_feedforward import SimpleFeedForwardEstimator
from gluonts.mx.trainer import Trainer

# %%
estimator = SimpleFeedForwardEstimator(
    num_hidden_dimensions=[10],
    prediction_length=dataset.metadata.prediction_length,
    context_length=100,
    freq=dataset.metadata.freq,
    trainer=Trainer(ctx="cpu",
                    epochs=5,
                    learning_rate=1e-3,
                    num_batches_per_epoch=100
                   )
)

# %%
predictor = estimator.train(dataset.train)
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# learning rate from ``lr_scheduler`` has been overwritten by ``learning_rate`` in optimizer.
# ...
# 100%|██████████| 100/100 [00:01<00:00, 76.47it/s, epoch=5/5, avg_epoch_loss=4.73]

# %%
from gluonts.evaluation.backtest import make_evaluation_predictions

# %%
forecast_it, ts_it = make_evaluation_predictions(
    dataset=dataset.test,  # test dataset
    predictor=predictor,  # predictor
    num_samples=100,  # number of sample paths we want for evaluation
)

# %%
forecasts = list(forecast_it)
tss = list(ts_it)

# %%
ts_entry = tss[0]

# %%
np.array(ts_entry[:5]).reshape(-1,)
# Out:
# array([605., 586., 586., 559., 511.], dtype=float32)

# %%
dataset_test_entry = next(iter(dataset.test))

# %%
dataset_test_entry['target'][:5]
# Out:
# array([605., 586., 586., 559., 511.], dtype=float32)

# %%
forecast_entry = forecasts[0]

# %%
print(f"Number of sample paths: {forecast_entry.num_samples}")
print(f"Dimension of samples: {forecast_entry.samples.shape}")
print(f"Start date of the forecast window: {forecast_entry.start_date}")
print(f"Frequency of the time series: {forecast_entry.freq}")
# Out:
# Number of sample paths: 100
# Dimension of samples: (100, 48)
# Start date of the forecast window: 1750-01-30 04:00:00
# Frequency of the time series: H

# %%
print(f"Mean of the future window:\n {forecast_entry.mean}")
print(f"0.5-quantile (median) of the future window:\n {forecast_entry.quantile(0.5)}")
# Out:
# Mean of the future window:
#  [585.9112  655.0803  549.7651  484.1341  487.64343 508.41583 460.72302
#  518.66815 488.70673 533.9557  555.6348  601.985   738.11505 783.5114
#  805.67236 898.99634 829.50775 935.4228  886.04456 904.8378  819.2238
#  832.38666 760.113   760.8324  598.11255 571.4565  523.04376 489.8902
#  519.7812  535.7835  459.18793 461.492   487.09192 532.47125 619.98694
#  713.40283 772.2635  815.5807  841.5394  869.146   885.3006  922.01227
#  883.3322  961.4551  945.5873  832.33295 723.9412  704.9766 ]
# 0.5-quantile (median) of the future window:
#  [601.2428  640.58575 561.5464  488.75504 460.35577 516.8464  476.7675
#  528.4076  491.02316 517.2996  550.1946  593.63983 754.61176 794.68427
#  809.8425  913.5111  857.5472  940.73175 888.5425  900.7828  844.4415
#  816.0612  755.09424 748.3047  603.23517 580.356   523.5175  504.0355
#  526.9886  540.93225 454.8492  453.51007 481.78128 529.40594 610.1258
# ...

# %%
def plot_prob_forecasts(ts_entry, forecast_entry):
    plot_length = 150
    prediction_intervals = (50.0, 90.0)
    legend = ["observations", "median prediction"] + [f"{k}% prediction interval" for k in prediction_intervals][::-1]

    fig, ax = plt.subplots(1, 1, figsize=(10, 7))
    ts_entry[-plot_length:].plot(ax=ax)  # plot the time series
    forecast_entry.plot(prediction_intervals=prediction_intervals, color='g')
    plt.grid(which="both")
    plt.legend(legend, loc="upper left")
    plt.show()

# %%
plot_prob_forecasts(ts_entry, forecast_entry)

# %%
from gluonts.evaluation import Evaluator

# %%
evaluator = Evaluator(quantiles=[0.1, 0.5, 0.9])
agg_metrics, item_metrics = evaluator(iter(tss), iter(forecasts), num_series=len(dataset.test))
# Out:
# Running evaluation: 100%|██████████| 414/414 [00:00<00:00, 16325.47it/s]

# %%
print(json.dumps(agg_metrics, indent=4))
# Out:
# {
#     "MSE": 10745023.876190426,
#     "abs_error": 10508458.194160461,
#     "abs_target_sum": 145558863.59960938,
#     "abs_target_mean": 7324.822041043147,
#     "seasonal_error": 336.9046924038302,
#     "MASE": 4.0476515717477115,
#     "MAPE": 0.25717768862017615,
#     "sMAPE": 0.19772202304408917,
#     "OWA": NaN,
#     "MSIS": 64.6837265625711,
#     "QuantileLoss[0.1]": 5051610.732116794,
#     "Coverage[0.1]": 0.09968800322061187,
#     "QuantileLoss[0.5]": 10508458.300687313,
#     "Coverage[0.5]": 0.4988929146537841,
#     "QuantileLoss[0.9]": 7312004.123609161,
#     "Coverage[0.9]": 0.8836050724637684,
#     "RMSE": 3277.960322546694,
#     "NRMSE": 0.44751398794118297,
#     "ND": 0.07219387355940214,
#     "wQuantileLoss[0.1]": 0.03470493384732876,
#     "wQuantileLoss[0.5]": 0.07219387429124938,
#     "wQuantileLoss[0.9]": 0.05023400116479601,
#     "mean_absolute_QuantileLoss": 7624024.38547109,
#     "mean_wQuantileLoss": 0.052377603101124715,
# ...

# %%
item_metrics.head()
# Out:
#    item_id            MSE  ...  QuantileLoss[0.9]  Coverage[0.9]
# 0      0.0    3361.122721  ...        1552.222180          1.000
# 1      1.0  187301.458333  ...        8836.603320          1.000
# 2      2.0   27484.906250  ...        1868.828271          0.875
# 3      3.0  193037.854167  ...        8272.268555          1.000
# 4      4.0  131319.729167  ...        7646.040674          1.000
#
# [5 rows x 17 columns]
